# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
Trump = pd.read_csv(r"C:\users\kevin\Trump.csv")
Trump.head()
# Out:
#    Unnamed: 0         created_time  \
# 0           0  2017-03-23 01:33:54
# 1           1  2017-03-23 01:04:32
# 2           2  2017-03-23 01:03:18
# 3           3  2017-03-22 13:09:35
# 4           4  2017-03-21 18:12:05
#
#                                                 text              source  \
# 0  Spoke to U.K. Prime Minister Theresa May today...  Twitter for iPhone
# 1  RT @mitchellvii: Trump always ends up being ri...  Twitter for iPhone
# 2  RT @mitchellvii: EXACTLY AS I SAID - House Int...  Twitter for iPhone
# 3              Big day for healthcare. Working hard!  Twitter for iPhone
# 4  Today on #NationalAgDay, we honor our great Am...  Twitter for iPhone
#
#    favorite_count  retweet_count            hashtags      user_mentioned  \
# 0           54696          10042                  []                  []
# 1               0          10307                  []  [u'Bill Mitchell']
# 2               0           7657                  []  [u'Bill Mitchell']
# 3           75712          11211                  []                  []
# 4           59871          13673  [u'NationalAgDay']                  []
#
#   url_used media_used
# 0    False      False
# 1    False      False
# 2    False      False
# 3    False      False
# 4     True      False

# %%
Trump["hashtag"] = [len(Trump["hashtags"].iloc[i])>2 for i in xrange(Trump.shape[0])]

Source_hashtag = pd.crosstab(index=Trump["hashtag"], columns=Trump["source"], margins = True)
Source_hashtag.index= ["No hashtag","have hashtag","All"]
Source_hashtag
# Out:
# source        Instagram  Media Studio  Periscope  Twitter Ads  \
# No hashtag            2             0          0            1
# have hashtag          0             1          1            0
# All                   2             1          1            1
#
# source        Twitter Web Client  Twitter for Android  Twitter for iPad  \
# No hashtag                   158                 1323                 9
# have hashtag                 107                   95                13
# All                          265                 1418                22
#
# source        Twitter for iPhone   All
# No hashtag                   833  2326
# have hashtag                 695   912
# All                         1528  3238

# %%
hashtag_tweet = Trump.groupby(by=["source","hashtag"]).count().reset_index()[["source","hashtag","text"]]
hashtag_tweet = pd.concat([hashtag_tweet[hashtag_tweet["source"] == "Twitter for Android"],hashtag_tweet[hashtag_tweet["source"] == "Twitter for iPhone"]])
hashtag_tweet
# Out:
#                  source hashtag  text
# 6   Twitter for Android   False  1323
# 7   Twitter for Android    True    95
# 10   Twitter for iPhone   False   833
# 11   Twitter for iPhone    True   695

# %%
import math

# %%
plt.rcParams['figure.figsize'] = (6, 4)
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 16

fig, ax = plt.subplots()
index = np.arange(2)
bar_width = 0.25

number_hashtag = hashtag_tweet[hashtag_tweet["hashtag"]==True]["text"]
number_no =  hashtag_tweet[hashtag_tweet["hashtag"]!=True]["text"]

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, number_hashtag, bar_width,
                 alpha=opacity,
                 color='b',
                 label='hashtag')

rects2 = plt.bar(index + bar_width, number_no, bar_width,
                 alpha=opacity,
                 color='r',
                 label='no hashtag')

plt.xlabel('sources',size=20)
plt.ylabel('Number of tweets',size=20)
#plt.title('')
plt.xticks(index + bar_width / 2, ('Android', 'iPhone'))
plt.legend(prop={"size":16})

plt.tight_layout()
plt.show()
fig.savefig("hashtag_proportion.png")

# %%
Trump["quoted"] = ['"' in Trump["text"].iloc[i] for i in xrange(Trump.shape[0])]

Source_quoted = pd.crosstab(index=Trump["quoted"], columns=Trump["source"], margins = True)
Source_quoted.index= ["Not quoted","quoted","All"]
Source_quoted
# Out:
# source      Instagram  Media Studio  Periscope  Twitter Ads  \
# Not quoted          2             1          1            1
# quoted              0             0          0            0
# All                 2             1          1            1
#
# source      Twitter Web Client  Twitter for Android  Twitter for iPad  \
# Not quoted                 246                 1001                22
# quoted                      19                  417                 0
# All                        265                 1418                22
#
# source      Twitter for iPhone   All
# Not quoted                1477  2751
# quoted                      51   487
# All                       1528  3238

# %%
quoted_tweet = Trump.groupby(by=["source","quoted"]).count().reset_index()[["source","quoted","text"]]
quoted_tweet = pd.concat([quoted_tweet[quoted_tweet["source"] == "Twitter for Android"],quoted_tweet[quoted_tweet["source"] == "Twitter for iPhone"]])
quoted_tweet
# Out:
#                  source quoted  text
# 6   Twitter for Android  False  1001
# 7   Twitter for Android   True   417
# 9    Twitter for iPhone  False  1477
# 10   Twitter for iPhone   True    51

# %%
fig, ax = plt.subplots()
index = np.arange(2)
bar_width = 0.25

number_quoted = quoted_tweet[quoted_tweet["quoted"]==True]["text"]
number_not_quoted =  quoted_tweet[quoted_tweet["quoted"]!=True]["text"]

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, number_quoted, bar_width,
                 alpha=opacity,
                 color='b',
                 label='quoted')

rects2 = plt.bar(index + bar_width, number_not_quoted, bar_width,
                 alpha=opacity,
                 color='r',
                 label='not quoted')

plt.xlabel('sources',size=20)
plt.ylabel('Number of tweets',size=20)
#plt.title('')
plt.xticks(index + bar_width / 2, ('Android', 'iPhone'))
plt.legend(prop={"size":16})

plt.tight_layout()
plt.show()
fig.savefig("quoted.png")

# %%
Trump["at"] = [len(Trump["user_mentioned"].iloc[i])>2 for i in xrange(Trump.shape[0])]

Source_at = pd.crosstab(index=Trump["at"], columns=Trump["source"], margins = True)
Source_at.index= ["No at","at","All"]
Source_at
# Out:
# source  Instagram  Media Studio  Periscope  Twitter Ads  Twitter Web Client  \
# No at           2             1          1            1                 170
# at              0             0          0            0                  95
# All             2             1          1            1                 265
#
# source  Twitter for Android  Twitter for iPad  Twitter for iPhone   All
# No at                   914                16                1155  2260
# at                      504                 6                 373   978
# All                    1418                22                1528  3238

# %%
at_tweet = Trump.groupby(by=["source","at"]).count().reset_index()[["source","at","text"]]
at_tweet = pd.concat([at_tweet[at_tweet["source"] == "Twitter for Android"],at_tweet[at_tweet["source"] == "Twitter for iPhone"]])
at_tweet
# Out:
#                  source     at  text
# 6   Twitter for Android  False   914
# 7   Twitter for Android   True   504
# 10   Twitter for iPhone  False  1155
# 11   Twitter for iPhone   True   373

# %%
fig, ax = plt.subplots()
index = np.arange(2)
bar_width = 0.25

number_at = at_tweet[at_tweet["at"]==True]["text"]
number_no_at = at_tweet[at_tweet["at"]!=True]["text"]

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, number_at, bar_width,
                 alpha=opacity,
                 color='b',
                 label='@')

rects2 = plt.bar(index + bar_width, number_no_at, bar_width,
                 alpha=opacity,
                 color='r',
                 label='no @')

plt.xlabel('sources',size=20)
plt.ylabel('Number of tweets',size=20)
#plt.title('')
plt.xticks(index + bar_width / 2, ('Android', 'iPhone'))
plt.legend(prop={"size":16})

plt.tight_layout()
plt.show()
fig.savefig("at.png")

# %%
Trump["url_media"] = [Trump["url_used"].iloc[i] or Trump["media_used"].iloc[i] for i in xrange(Trump.shape[0])]

Source_link = pd.crosstab(index=Trump["url_media"], columns=Trump["source"], margins = True)
Source_link.index= ["No link","link","All"]
Source_link
# Out:
# source   Instagram  Media Studio  Periscope  Twitter Ads  Twitter Web Client  \
# No link          0             0          0            0                 146
# link             2             1          1            1                 119
# All              2             1          1            1                 265
#
# source   Twitter for Android  Twitter for iPad  Twitter for iPhone   All
# No link                 1339                 5                 410  1900
# link                      79                17                1118  1338
# All                     1418                22                1528  3238

# %%
link_tweet = Trump.groupby(by=["source","url_media"]).count().reset_index()[["source","url_media","text"]]
link_tweet = pd.concat([link_tweet[link_tweet["source"] == "Twitter for Android"],link_tweet[link_tweet["source"] == "Twitter for iPhone"]])
link_tweet
# Out:
#                  source url_media  text
# 6   Twitter for Android     False  1339
# 7   Twitter for Android      True    79
# 10   Twitter for iPhone     False   410
# 11   Twitter for iPhone      True  1118

# %%
(float(1118)/float(410))/(float(79)/float(1339))
# Out:
# 46.218030256251936

# %%
fig, ax = plt.subplots()
index = np.arange(2)
bar_width = 0.25

number_link = link_tweet[link_tweet["url_media"]==True]["text"]
number_no_link = link_tweet[link_tweet["url_media"]!=True]["text"]

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, number_link, bar_width,
                 alpha=opacity,
                 color='b',
                 label='link')

rects2 = plt.bar(index + bar_width, number_no_link, bar_width,
                 alpha=opacity,
                 color='r',
                 label='no link')

plt.xlabel('sources',size=20)
plt.ylabel('Number of tweets',size=20)
#plt.title('')
plt.xticks(index + bar_width / 2, ('Android', 'iPhone'))
plt.legend(prop={"size":16})

plt.tight_layout()
plt.show()
fig.savefig("link.png")

# %%
Trump["self"] = Trump["text"].str.lower().str.contains(r" i | me | my | mine | myself")
Source_self = pd.crosstab(index=Trump["self"], columns=Trump["source"], margins = True)
Source_link.index= ["no_self","self","All"]
Source_self
# Out:
# source  Instagram  Media Studio  Periscope  Twitter Ads  Twitter Web Client  \
# self
# False           2             1          0            1                 225
# True            0             0          1            0                  40
# All             2             1          1            1                 265
#
# source  Twitter for Android  Twitter for iPad  Twitter for iPhone   All
# self
# False                  1046                19                1229  2523
# True                    372                 3                 299   715
# All                    1418                22                1528  3238

# %%
self_tweet = Trump.groupby(by=["source","self"]).count().reset_index()[["source","self","text"]]
self_tweet = pd.concat([self_tweet[self_tweet["source"] == "Twitter for Android"],self_tweet[self_tweet["source"] == "Twitter for iPhone"]])
self_tweet
# Out:
#                  source   self  text
# 6   Twitter for Android  False  1046
# 7   Twitter for Android   True   372
# 10   Twitter for iPhone  False  1229
# 11   Twitter for iPhone   True   299

# %%
fig, ax = plt.subplots()
index = np.arange(2)
bar_width = 0.25

number_self = self_tweet[self_tweet["self"]==True]["text"]
number_no_self = self_tweet[self_tweet["self"]!=True]["text"]

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, number_self, bar_width,
                 alpha=opacity,
                 color='b',
                 label='self')

rects2 = plt.bar(index + bar_width, number_no_self, bar_width,
                 alpha=opacity,
                 color='r',
                 label='no self')

plt.xlabel('sources',size=20)
plt.ylabel('Number of tweets',size=20)
#plt.title('')
plt.xticks(index + bar_width / 2, ('Android', 'iPhone'))
plt.legend(prop={"size":16})

plt.tight_layout()
plt.show()
fig.savefig("self.png")

# %%
sum(Trump["self"])
# Out:
# 715

# %%
Obama["self"] = Obama["text"].str.lower().str.contains(r" i | me | my | mine | myself")
sum(Obama["self"])
# Out:
# 77

# %%
Hillary =

# %%
Trump
# Out:
#       Unnamed: 0        created_time  \
# 0              0 2017-03-23 01:33:54
# 1              1 2017-03-23 01:04:32
# 2              2 2017-03-23 01:03:18
# 3              3 2017-03-22 13:09:35
# 4              4 2017-03-21 18:12:05
# 5              5 2017-03-21 17:33:23
# 6              6 2017-03-21 17:02:31
# 7              7 2017-03-21 02:18:20
# 8              8 2017-03-20 23:03:36
# 9              9 2017-03-20 17:15:18
# 10            10 2017-03-20 13:14:49
# 11            11 2017-03-20 12:35:14
# 12            12 2017-03-20 11:02:57
# 13            13 2017-03-20 10:49:48
# 14            14 2017-03-20 10:35:28
# 15            15 2017-03-19 20:20:22
# 16            16 2017-03-18 13:23:37
# 17            17 2017-03-18 13:15:41
# 18            18 2017-03-17 15:39:10
# 19            19 2017-03-17 14:07:26
# 20            20 2017-03-17 13:07:15
# 21            21 2017-03-17 12:34:17
# 22            22 2017-03-17 12:30:25
# 23            23 2017-03-17 12:26:12
# 24            24 2017-03-17 12:20:22
# 25            25 2017-03-17 12:12:04
# 26            26 2017-03-17 09:35:58
# 27            27 2017-03-16 22:43:32
# 28            28 2017-03-16 21:54:02
# 29            29 2017-03-16 21:43:07
# ...          ...                 ...
# 3208        3208 2016-03-29 19:35:20
# 3209        3209 2016-03-29 19:18:53
# 3210        3210 2016-03-29 19:05:15
# 3211        3211 2016-03-29 16:44:36
# 3212        3212 2016-03-29 16:41:33
# 3213        3213 2016-03-29 14:45:37
# 3214        3214 2016-03-29 14:16:19
# 3215        3215 2016-03-29 13:34:36
# 3216        3216 2016-03-29 01:07:23
# 3217        3217 2016-03-29 01:04:06
# 3218        3218 2016-03-29 00:57:35
# 3219        3219 2016-03-28 23:13:27
# 3220        3220 2016-03-28 22:34:40
# 3221        3221 2016-03-28 22:34:11
# 3222        3222 2016-03-28 22:22:11
# 3223        3223 2016-03-28 22:18:21
# 3224        3224 2016-03-28 17:25:23
# 3225        3225 2016-03-28 14:45:44
# 3226        3226 2016-03-28 12:05:54
# 3227        3227 2016-03-28 11:18:50
# 3228        3228 2016-03-28 01:36:28
# 3229        3229 2016-03-28 01:17:57
# 3230        3230 2016-03-27 22:16:52
# 3231        3231 2016-03-27 21:11:43
# 3232        3232 2016-03-27 20:55:59
# 3233        3233 2016-03-27 20:37:17
# 3234        3234 2016-03-27 19:41:16
# 3235        3235 2016-03-27 14:23:51
# 3236        3236 2016-03-27 14:14:05
# 3237        3237 2016-03-27 13:02:06
#
#                                                    text               source  \
# 0     Spoke to U.K. Prime Minister Theresa May today...   Twitter for iPhone
# 1     RT @mitchellvii: Trump always ends up being ri...   Twitter for iPhone
# 2     RT @mitchellvii: EXACTLY AS I SAID - House Int...   Twitter for iPhone
# 3                 Big day for healthcare. Working hard!   Twitter for iPhone
# 4     Today on #NationalAgDay, we honor our great Am...   Twitter for iPhone
# 5     Honored to sign S.442 today. With this legisla...   Twitter for iPhone
# 6     Joined the @HouseGOP Conference this morning a...   Twitter for iPhone
# 7     Thank you Louisville, Kentucky. Together, we w...   Twitter for iPhone
# 8     Thank you Louisville, Kentucky- on my way! #MA...   Twitter for iPhone
# 9     Congratulations Eric &amp; Lara. Very proud an...   Twitter for iPhone
# 10    What about all of the contact with the Clinton...   Twitter for iPhone
# 11    Just heard Fake News CNN is doing polls again ...   Twitter for iPhone
# 12    The real story that Congress, the FBI and all ...   Twitter for iPhone
# 13    The Democrats made up and pushed the Russian s...   Twitter for iPhone
# 14    James Clapper and others stated that there is ...   Twitter for iPhone
# 15    #ICYMI: Weekly Address \r\n➡️https://t.co/ckVx...   Twitter for iPhone
# 16    ...vast sums of money to NATO &amp; the United...   Twitter for iPhone
# 17    Despite what you have heard from the FAKE NEWS...   Twitter for iPhone
# 18    Great meeting with the @RepublicanStudy Commit...   Twitter for iPhone
# 19    "The President Changed. So Has Small Businesse...   Twitter for iPhone
# 20    North Korea is behaving very badly. They have ...   Twitter for iPhone
# 21    RT @foxandfriends: FOX NEWS ALERT: Jihadis usi...   Twitter for iPhone
# 22    RT @foxandfriends: VIDEO: Rep. Scalise — GOP a...   Twitter for iPhone
# 23    RT @AmericaFirstPol: MAJOR IMPACT: @POTUS Trum...   Twitter for iPhone
# 24    RT @FoxNews: Jobs created in February. https:/...   Twitter for iPhone
# 25    Happy Lá Fheile Phadraig to all of my great Ir...   Twitter for iPhone
# 26    RT @DiamondandSilk: When the President says "Y...   Twitter for iPhone
# 27    My representatives had a great meeting w/ the ...   Twitter for iPhone
# 28    Great progress on healthcare. Improvements bei...   Twitter for iPhone
# 29    RT @USHCC: USHCC was delighted to host @Ivanka...   Twitter for iPhone
# ...                                                 ...                  ...
# 3208  Why is this reporter touching me as I leave ne...   Twitter for iPhone
# 3209  This was the reporters statement- when she fou...   Twitter for iPhone
# 3210  Victory press conference was over. \r\nWhy is ...   Twitter for iPhone
# 3211  Why aren't people looking at this reporters ea...  Twitter for Android
# 3212  Wow, Corey Lewandowski, my campaign manager an...  Twitter for Android
# 3213  How come the @TODAYshow &amp; @chucktodd show ...  Twitter for Android
# 3214  I have millions more votes/hundreds more dels ...  Twitter for Android
# 3215  Wow, @CNN has nothing but my opponents on thei...  Twitter for Android
# 3216  We need to secure our borders ASAP. No games, ...  Twitter for Android
# 3217  Lyin' Ted, I have already beaten you in all de...  Twitter for Android
# 3218  Lyin'Ted Cruz is weak &amp; losing big, so now...  Twitter for Android
# 3219  After the way I beat Gov. Scott Walker (and Je...  Twitter for Android
# 3220  "@PaulaDuvall2:  Cruz will say anything that i...  Twitter for Android
# 3221  Just released that international gangs are all...  Twitter for Android
# 3222  "@wolfblitzer:  Campaign-to-date popular GOP t...  Twitter for Android
# 3223  Ted Cruz is incensed that I want to refocus NA...  Twitter for Android
# 3224  A detainee released from Gitmo has killed an A...  Twitter for Android
# 3225  "Kirsten Powers: Anti- Trump Operative was Agg...   Twitter for iPhone
# 3226  "@nellalda: @realDonaldTrump We stand by Trump...  Twitter for Android
# 3227  I will be interviewed on @foxandfriends at 7:3...  Twitter for Android
# 3228  "@VictorConkle: #WIPrimary @realDonaldTrump wi...  Twitter for Android
# 3229  The United States cannot continue to make such...  Twitter for Android
# 3230  See Lyin' Ted, even the @DailyBeast (no fan of...   Twitter for iPhone
# 3231  Just to show you how unfair Republican primary...  Twitter for Android
# 3232  Why can't the pundits be honest? Hopefully we ...  Twitter for Android
# 3233  Another radical Islamic attack, this time in P...  Twitter for Android
# 3234             Happy Easter to all, have a great day!  Twitter for Android
# 3235  My statement on NATO being obsolete and dispro...  Twitter for Android
# 3236  Wow, sleepy eyes @chucktodd is at it again. He...  Twitter for Android
# 3237  I am interviewed on This Week on @ABC this mor...  Twitter for Android
#
#       favorite_count  retweet_count                                  hashtags  \
# 0              54696          10042                                        []
# 1                  0          10307                                        []
# 2                  0           7657                                        []
# 3              75712          11211                                        []
# 4              59871          13673                        [u'NationalAgDay']
# 5              59658          13855                                        []
# 6              31502           5558                 [u'PassTheBill', u'MAGA']
# 7              71497          14129                                        []
# 8              57913          10793                                 [u'MAGA']
# 9              96792          13227                                        []
# 10             78929          21139                                        []
# 11             87154          18183                                        []
# 12             60953          14588                                        []
# 13             85518          20061                                        []
# 14             68731          16881                                        []
# 15             35067           7316                                [u'ICYMI']
# 16             85893          19498                                        []
# 17             94469          21133                                        []
# 18             45789           8203                                        []
# 19             50760          11414                                        []
# 20             88400          20843                                        []
# 21                 0          11247                                        []
# 22                 0           3358                                        []
# 23                 0           5909                                 [u'MAGA']
# 24                 0           7514                                        []
# 25             68061          12192                                        []
# 26                 0          10725                                        []
# 27             64090          10559                                        []
# 28             69851          11174                                        []
# 29                 0           7266                                        []
# ...              ...            ...                                       ...
# 3208           27576          12813                                        []
# 3209           14497           6587                                        []
# 3210           27514          10869                                        []
# 3211           14582           5419                                        []
# 3212           17440           6279                                        []
# 3213           12755           4399                                        []
# 3214           24043           7460                                        []
# 3215           19531           5591                                        []
# 3216           24334           9574                                        []
# 3217           17879           5371                                        []
# 3218           16746           4905                                        []
# 3219           13898           4371                                        []
# 3220            9760           2760                                        []
# 3221           15844           5923                                        []
# 3222           10099           3561                                        []
# 3223           12735           4373                                        []
# 3224           20651           9104                                        []
# 3225            8515           4229                                        []
# 3226           12507           3589                                        []
# 3227           13914           3436                                        []
# 3228            8641           3182  [u'WIPrimary', u'MakeAmericaGreatAgain']
# 3229           22044           7094                                        []
# 3230           14338           7247                                        []
# 3231           27490          10200                                        []
# 3232           17198           5544                                        []
# 3233           27018          11185                                        []
# 3234           31930           9232                                        []
# 3235           18481           6453                                        []
# 3236           13323           3776                                        []
# 3237           10054           2460                                        []
#
#                                          user_mentioned url_used media_used  \
# 0                                                    []    False      False
# 1                                    [u'Bill Mitchell']    False      False
# 2                                    [u'Bill Mitchell']    False      False
# 3                                                    []    False      False
# 4                                                    []     True      False
# 5                                             [u'NASA']     True      False
# 6                                [u'House Republicans']     True      False
# 7                                                    []    False       True
# 8                                                    []    False       True
# 9                                                    []     True      False
# 10                                                   []    False      False
# 11                                                   []    False      False
# 12                                                   []    False      False
# 13                                                   []    False      False
# 14                                                   []    False      False
# 15                                                   []     True       True
# 16                                                   []    False      False
# 17                                                   []    False      False
# 18                         [u'RSC', u'The White House']    False       True
# 19                                                   []     True      False
# 20                                                   []    False      False
# 21           [u'FOX & friends', u'Fox & Friends First']    False       True
# 22                                   [u'FOX & friends']     True      False
# 23        [u'AmericaFirstPolicies', u'President Trump']    False      False
# 24                                        [u'Fox News']    False       True
# 25                                                   []    False      False
# 26                            [u'Diamond and Silk\xae']    False      False
# 27                                                   []    False      False
# 28                                                   []    False      False
# 29                          [u'USHCC', u'Ivanka Trump']    False      False
# ...                                                 ...      ...        ...
# 3208                                                 []    False       True
# 3209                                                 []    False       True
# 3210                                                 []    False       True
# 3211                                                 []    False      False
# 3212                                                 []    False      False
# 3213             [u'TODAY', u'Chuck Todd', u'NBC News']    False      False
# 3214                                                 []    False      False
# 3215                                           [u'CNN']    False      False
# 3216                                                 []    False      False
# 3217                                                 []    False      False
# 3218                                                 []    False      False
# 3219                                                 []    False      False
# 3220                                  [u'Paula Duvall']    False      False
# 3221                                                 []    False      False
# 3222  [u'Wolf Blitzer', u'Donald J. Trump', u'Ted Cr...    False      False
# 3223                                                 []    False      False
# 3224                                                 []    False      False
# 3225                                                 []     True      False
# 3226           [u'Trump Supporter', u'Donald J. Trump']    False      False
# 3227                                 [u'FOX & friends']    False      False
# 3228        [u'Patriot Vic Revere', u'Donald J. Trump']     True      False
# 3229                                                 []    False      False
# 3230                               [u'The Daily Beast']    False       True
# 3231                                                 []    False      False
# 3232                                                 []    False      False
# 3233                                                 []    False      False
# 3234                                                 []    False      False
# 3235                                                 []    False      False
# 3236                                    [u'Chuck Todd']    False      False
# 3237                                      [u'ABC News']    False      False
#
#      hashtag quoted     at url_media  sentiment negative  year  week   self
# 0      False  False  False     False  -0.001600     True  2017    12  False
# 1      False  False   True     False  -0.023214     True  2017    12  False
# 2      False  False   True     False   0.036525    False  2017    12   True
# 3      False  False  False     False   0.031480    False  2017    12  False
# 4       True  False  False      True   0.045440    False  2017    12  False
# 5      False  False   True      True   0.034706    False  2017    12  False
# 6       True  False   True      True   0.000000    False  2017    12  False
# 7      False  False  False      True   0.046464    False  2017    12  False
# 8       True  False  False      True   0.000000    False  2017    12   True
# 9      False  False  False      True   0.171296    False  2017    12  False
# 10     False  False  False     False   0.022228    False  2017    12  False
# 11     False  False  False     False  -0.027806     True  2017    12  False
# 12     False  False  False     False   0.013375    False  2017    12  False
# 13     False  False  False     False  -0.034034     True  2017    12  False
# 14     False  False  False     False  -0.007519     True  2017    12  False
# 15      True  False  False      True  -0.020833     True  2017    11  False
# 16     False  False  False     False   0.005368    False  2017    11  False
# 17     False  False  False     False  -0.041540     True  2017    11   True
# 18     False  False   True      True   0.040414    False  2017    11  False
# 19     False   True  False      True  -0.027473     True  2017    11  False
# 20     False   True  False     False   0.002170    False  2017    11  False
# 21     False  False   True      True  -0.005301     True  2017    11  False
# 22     False  False   True      True   0.042962    False  2017    11  False
# 23      True  False   True     False   0.037264    False  2017    11  False
# 24     False  False   True      True  -0.003064     True  2017    11  False
# 25     False  False  False     False   0.116071    False  2017    11   True
# 26     False   True   True     False  -0.005766     True  2017    11  False
# 27     False  False  False     False   0.026796    False  2017    11  False
# 28     False  False  False     False   0.078348    False  2017    11  False
# 29     False  False   True     False   0.004439    False  2017    11  False
# ...      ...    ...    ...       ...        ...      ...   ...   ...    ...
# 3208   False  False  False      True   0.013119    False  2016    13   True
# 3209   False  False  False      True   0.007956    False  2016    13   True
# 3210   False  False  False      True   0.012809    False  2016    13   True
# 3211   False  False  False     False   0.002141    False  2016    13  False
# 3212   False  False  False     False   0.023944    False  2016    13   True
# 3213   False  False   True     False   0.008625    False  2016    13   True
# 3214   False  False  False     False  -0.000172     True  2016    13  False
# 3215   False  False   True     False   0.008013    False  2016    13   True
# 3216   False  False  False     False   0.000036    False  2016    13  False
# 3217   False  False  False     False   0.014463    False  2016    13   True
# 3218   False  False  False     False  -0.020013     True  2016    13   True
# 3219   False  False  False     False   0.010214    False  2016    13   True
# 3220   False   True   True     False   0.023512    False  2016    13  False
# 3221   False  False  False     False  -0.028472     True  2016    13   True
# 3222   False   True   True     False  -0.004355     True  2016    13  False
# 3223   False  False  False     False  -0.018400     True  2016    13   True
# 3224   False   True  False     False  -0.023611     True  2016    13  False
# 3225   False   True  False      True   0.047848    False  2016    13  False
# 3226   False   True   True     False  -0.003401     True  2016    13  False
# 3227   False  False   True     False   0.029621    False  2016    13  False
# 3228    True   True   True      True  -0.013393     True  2016    13  False
# 3229   False  False  False     False  -0.016782     True  2016    13  False
# 3230   False  False   True      True   0.006471    False  2016    12  False
# 3231   False  False  False     False   0.009161    False  2016    12   True
# 3232   False  False  False     False   0.056367    False  2016    12   True
# 3233   False  False  False     False   0.010027    False  2016    12   True
# 3234   False  False  False     False   0.150000    False  2016    12  False
# 3235   False  False  False     False   0.039950    False  2016    12  False
# 3236   False  False   True     False   0.077072    False  2016    12   True
# 3237   False  False   True     False   0.000000    False  2016    12  False
#
# [3238 rows x 19 columns]

# %% [markdown]
# <p>Trump's tweets from Android are more likely to quote others, are more likely to at(@) others. However, most of the hashtags(#) and links(url and media) are from iPhone.</p>

# %%
import nltk
from nltk.corpus import sentiwordnet as swn

def sentiment_of_word(s):
    '''
    Based on corpus "sentiwordnet", get the positive-negative score of a word.
    Input: s(string): a word for judgment.
    Output: score(float): the positive-negative score of the word.
    '''
    l = list(swn.senti_synsets(s))
    score = 0
    if len(l) > 0:
        for item in l:
            score += item.pos_score()
            score -= item.neg_score()
        score = score/len(l)
    return score

# %%
from nltk.corpus import stopwords

def sentiment_of_tweet(d):
    '''
    Based on sentiment_of_word, get the average score of a sentence or a paragraph (after removing stopwords).
    Input: d(string): a sentence or a paragraph.
    Output: average positive-negative score.
    '''
    stop = set(stopwords.words("english"))
    words = [word for word in d.lower().split() if word not in stop]
    score = 0
    for word in words:
        try:
            score += sentiment_of_word(word)
        except:
            pass
    return(score/len(words))

# %% [markdown]
# First based on a corpus called "sentiwordnet" in module nltk, we are able to find the positive/negative score for each word.
# Then we define a function to get the average the scores for all the words(delete stopwords at first) in a tweet text.
# So we can find whether one tweet is positive or negative.
# <table style="width:50%">
#   <tr>
#     <th>source</th>
#     <th>Twitter for Android</th>
#     <th>Twitter for iPhone</th>
#     <th>All</th>
#   </tr>
#   <tr>
#     <td>positive</td>
#     <td>839</td>
#     <td>1123</td>
#     <td>1962</td>
#   </tr>
#   <tr>
#     <td>negative</td>
#     <td>579</td>
#     <td>405</td>
#     <td>984</td>
#   </tr>
#   <tr>
#     <td>All</td>
#     <td>1418</td>
#     <td>1528</td>
#     <td>2946</td>
#   </tr>
# </table>
# The proportion of negative tweets from Android(40.8%) are much higher than that for iPhone(26.5%). Then we apply chi-square test.
# We find that the difference is signifiant. (p-value = 2.23e-86)

# %%
Trump["sentiment"] = [sentiment_of_tweet(text) for text in Trump["text"]]
Trump["negative"] = Trump["sentiment"]<0

# %%
Source_sentiment = pd.crosstab(index=Trump["negative"], columns=Trump["source"], margins = True)
Source_sentiment.index= ["positive","negative","All"]
Source_sentiment
# Out:
# source    Instagram  Media Studio  Periscope  Twitter Ads  Twitter Web Client  \
# positive          2             1          1            1                 144
# negative          0             0          0            0                 121
# All               2             1          1            1                 265
#
# source    Twitter for Android  Twitter for iPad  Twitter for iPhone   All
# positive                  839                18                1123  2129
# negative                  579                 4                 405  1109
# All                      1418                22                1528  3238

# %%
#Chi_square test for Android and iPhone
import numpy as np
from scipy.stats import chisquare
obs = np.array([[Trump[(Trump["sentiment"]<0) & (Trump["source"] == "Twitter for Android")].shape[0],
                 Trump[(Trump["sentiment"]>=0) & (Trump["source"] == "Twitter for Android")].shape[0]],
                [Trump[(Trump["sentiment"]<0) & (Trump["source"] == "Twitter for iPhone")].shape[0],
                 Trump[(Trump["sentiment"]>=0) & (Trump["source"] == "Twitter for iPhone")].shape[0]]])
chisquare(obs,axis=None)
# Out:
# Power_divergenceResult(statistic=399.98234894772577, pvalue=2.233462745254962e-86)

# %% [markdown]
# <p>We use Obama's tweets for comparison.</p>

# %%
Obama = pd.read_csv(r"C:\users\kevin\Obama.csv")
Obama.head()
# Out:
#    Unnamed: 0                  id         created_time  \
# 0           0  832675462325243906  2017-02-17 19:37:55
# 1           1  831527113211645959  2017-02-14 15:34:47
# 2           2  823230505546117120  2017-01-22 18:07:02
# 3           3  822553543479541761  2017-01-20 21:17:01
# 4           4  822550536469803009  2017-01-20 21:05:04
#
#                                                 text              source  \
# 0    We asked. You answered. https://t.co/mAJvko6VqR  Twitter Web Client
# 1  Happy Valentine’s Day, @michelleobama! Almost ...  Twitter Web Client
# 2  I read letters like these every single day. It...  Twitter Web Client
# 3  RT @ObamaFoundation: Add your voice: https://t...  Twitter Web Client
# 4  In the meantime, I want to hear what you're th...  Twitter Web Client
#
#    favorite_count  retweet_count     username
# 0          101664          23627  BarackObama
# 1         1057719         255894  BarackObama
# 2          232803          35037  BarackObama
# 3               0          48010  BarackObama
# 4          236278          54259  BarackObama

# %%
Obama["sentiment"] = [sentiment_of_tweet(text) for text in Obama["text"]]
Obama["negative"] = Obama["sentiment"]<0
Obama.groupby(by="negative").count()["id"]
# Out:
# negative
# False    2415
# True      810
# Name: id, dtype: int64

# %% [markdown]
# <p>For Obama, the proportion of negative tweets is about 25.1%. It is 26.5% for Trump's iPhone, and 40.8% for Trump's Android.</p>
# <p>The proportion of Trump's iPhone is close to Obama's. However, Trump's Android is extremely high.</p>

# %% [markdown]
# <p>Also, for Trump, we want to see whether his tweets' ratio of negative change over times.</p>

# %%
import datetime
Trump["created_time"] = [datetime.datetime.strptime(Trump["created_time"].iloc[i],"%Y-%m-%d %H:%M:%S") for i in xrange(Trump.shape[0])]

Trump["year"] = [Trump["created_time"].iloc[i].year for i in xrange(Trump.shape[0])]
Trump["week"] = [Trump["created_time"].iloc[i].week for i in xrange(Trump.shape[0])]

# %%
def return_year(i):
    '''
    For 2017-01-01, the year is 2017 but the week is 52. That is because in system that day belongs to the last week in 2016.
    '''
    if Trump["created_time"].iloc[i].year == 2017 and Trump["created_time"].iloc[i].month == 1 and Trump["created_time"].iloc[i].day == 1:
        return 2016
    else:
        return Trump["created_time"].iloc[i].year
    
Trump["year"] = [return_year(i) for i in xrange(Trump.shape[0])]

# %%
Trump_week = Trump.groupby(by=["year","week","source"]).count().reset_index()[["year","week","text","source"]].merge(Trump.groupby(by=["year","week","source"]).sum().reset_index()[["year","week","negative","source"]],on=["year","week","source"])
Trump_week.head()
# Out:
#    year  week  text               source  negative
# 0  2016    12     7  Twitter for Android       0.0
# 1  2016    12     1   Twitter for iPhone       0.0
# 2  2016    13     5   Twitter Web Client       2.0
# 3  2016    13    32  Twitter for Android      12.0
# 4  2016    13    35   Twitter for iPhone       7.0

# %%
Trump_week_total = Trump_week.groupby(by=["year","week"]).sum()
Trump_week_total = Trump_week_total.reset_index()
Trump_week_total.shape
# Out:
# (53, 4)

# %%
Trump_week_android = Trump_week[Trump_week["source"] == "Twitter for Android"]
Trump_week_android.shape
# Out:
# (51, 5)

# %%
Trump_week_iphone = Trump_week[Trump_week["source"] == "Twitter for iPhone"]
Trump_week_iphone = pd.concat([Trump_week_iphone.iloc[0:35],pd.DataFrame({"year":2016,"week":46,"id":0,"source":"Twitter for iPhone","negative":0},index=[20]),Trump_week_iphone.iloc[35:]])
Trump_week_iphone.shape
# Out:
# (53, 6)

# %%
plt.rcParams['figure.figsize'] = (16, 12)
plt.rcParams['ytick.labelsize'] = 16
fig,ax = plt.subplots()

xticks = range(0,Trump_week_android.shape[0],3)
labels = [datetime.datetime.strptime("{} {} 1".format(Trump_week_total["year"].iloc[i], Trump_week_total["week"].iloc[i]), '%Y %W %w').date() for i in xrange(Trump_week_total.shape[0])]
xlabels = [labels[index] for index in xticks]

ax.set_xticks(xticks)
ax.set_xticklabels(xlabels,rotation=40)

#week_total = list(Trump_week_total["negative"]/Trump_week_total["id"], label = "total)
week_android = list(Trump_week_android["negative"]/Trump_week_android["text"])
week_iphone = list(Trump_week_iphone["negative"]/Trump_week_iphone["text"])

#plt.plot(week_total)
plt.plot(week_android,label = "Android")
plt.plot(week_iphone, label = "iPhone")
plt.grid()
plt.legend(loc=2, prop={"size":30})
plt.title('Negative Tweets Ratio',size=24)
plt.ylabel("Negative Tweets Ratio",size=18)
plt.show()
fig.savefig("Ratio.png")

# %% [markdown]
# Based on these two Twitter source (Android and iPhone), we make a plot of the ratio of negative tweets and the total among of tweets in each week. In the time points when there is a peak of negative ratio of Android, we can find some events corresponing to them.
# <p>2016-05-09: Twitter war between Trump and Elizabeth Warren.
# <p>2016-07-02: Hillary Clinton's corruption scandal.
# <p>2016-07-12: Trump attacked Justice Ruth Bader Ginsburg.
# <p>2016-07-23: Wikileaks leaked 20000 emails revealed a bias against Bernie Sanders from the Democatic Party.
# <p>2016-09-09: Hillary's "Basket Of Deplorables"
# <p>2016-10-07: Sexual misconduct accusations against Trump.
# <p>2017-01-09: Meryl Streep's speech.
# <p>2017-01-20: Inauguration.
# <p>2017-02-13: Michael Flynn resigned.
